# %%
# %load train.py
import sys
import gym
import pylab
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.initializers import RandomUniform


# 정책 신경망과 가치 신경망 생성
class A2C(tf.keras.Model):
    def __init__(self, action_size):
        super(A2C, self).__init__()
        self.actor_fc = Dense(24, activation='tanh')
        self.actor_out = Dense(action_size, activation='softmax',
                               kernel_initializer=RandomUniform(-1e-3, 1e-3))
        self.critic_fc1 = Dense(24, activation='tanh')
        self.critic_fc2 = Dense(24, activation='tanh')
        self.critic_out = Dense(1,
                                kernel_initializer=RandomUniform(-1e-3, 1e-3))

    def call(self, x):
        actor_x = self.actor_fc(x)
        policy = self.actor_out(actor_x)

        critic_x = self.critic_fc1(x)
        critic_x = self.critic_fc2(critic_x)
        value = self.critic_out(critic_x)
        return policy, value


# 카트폴 예제에서의 액터-크리틱(A2C) 에이전트
class A2CAgent:
    def __init__(self, action_size):
        self.render = False

        # 행동의 크기 정의
        self.action_size = action_size

        # 액터-크리틱 하이퍼파라미터
        self.discount_factor = 0.99
        self.learning_rate = 0.001

        # 정책신경망과 가치신경망 생성
        self.model = A2C(self.action_size)
        # 최적화 알고리즘 설정, 미분값이 너무 커지는 현상을 막기 위해 clipnorm 설정
        self.optimizer = Adam(lr=self.learning_rate, clipnorm=5.0)

    # 정책신경망의 출력을 받아 확률적으로 행동을 선택
    def get_action(self, state):
        policy, _ = self.model(state)
        policy = np.array(policy[0])
        return np.random.choice(self.action_size, 1, p=policy)[0]

    # 각 타임스텝마다 정책신경망과 가치신경망을 업데이트
    def train_model(self, state, action, reward, next_state, done):
        model_params = self.model.trainable_variables
        with tf.GradientTape() as tape:
            policy, value = self.model(state)
            _, next_value = self.model(next_state)
            target = reward + (1 - done) * self.discount_factor * next_value[0]

            # 정책 신경망 오류 함수 구하기
            one_hot_action = tf.one_hot([action], self.action_size)
            action_prob = tf.reduce_sum(one_hot_action * policy, axis=1)
            cross_entropy = - tf.math.log(action_prob + 1e-5)
            advantage = tf.stop_gradient(target - value[0])
            actor_loss = tf.reduce_mean(cross_entropy * advantage)

            # 가치 신경망 오류 함수 구하기
            critic_loss = 0.5 * tf.square(tf.stop_gradient(target) - value[0])
            critic_loss = tf.reduce_mean(critic_loss)

            # 하나의 오류 함수로 만들기
            loss = 0.2 * actor_loss + critic_loss

        # 오류함수를 줄이는 방향으로 모델 업데이트
        grads = tape.gradient(loss, model_params)
        self.optimizer.apply_gradients(zip(grads, model_params))
        return np.array(loss)


if __name__ == "__main__":
    # CartPole-v1 환경, 최대 타임스텝 수가 500
    env = gym.make('CartPole-v1')
    # 환경으로부터 상태와 행동의 크기를 받아옴
    state_size = env.observation_space.shape[0]
    action_size = env.action_space.n

    # 액터-크리틱(A2C) 에이전트 생성
    agent = A2CAgent(action_size)

    scores, episodes = [], []
    score_avg = 0

    num_episode = 1000
    for e in range(num_episode):
        done = False
        score = 0
        loss_list = []
        state = env.reset()
        state = np.reshape(state, [1, state_size])

        while not done:
            if agent.render:
                env.render()

            action = agent.get_action(state)
            next_state, reward, done, info = env.step(action)
            next_state = np.reshape(next_state, [1, state_size])

            # 타임스텝마다 보상 0.1, 에피소드가 중간에 끝나면 -1 보상
            score += reward
            reward = 0.1 if not done or score == 500 else -1

            # 매 타임스텝마다 학습
            loss = agent.train_model(state, action, reward, next_state, done)
            loss_list.append(loss)
            state = next_state

            if done:
                # 에피소드마다 학습 결과 출력
                score_avg = 0.9 * score_avg + 0.1 * score if score_avg != 0 else score
                print("episode: {:3d} | score avg: {:3.2f} | loss: {:.3f}".format(
                      e, score_avg, np.mean(loss_list)))

                # 에피소드마다 학습 결과 그래프로 저장
                scores.append(score_avg)
                episodes.append(e)
                pylab.plot(episodes, scores, 'b')
                pylab.xlabel("episode")
                pylab.ylabel("average score")
                pylab.savefig("./save_graph/graph.png")

                # 이동 평균이 400 이상일 때 종료
                if score_avg > 400:
                    agent.model.save_weights("./save_model/model", save_format="tf")
                    sys.exit()
# Out:
# WARNING:tensorflow:Layer a2c is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# episode:   0 | score avg: 22.00 | loss: 0.040
# episode:   1 | score avg: 22.20 | loss: 0.041
# episode:   2 | score avg: 21.78 | loss: 0.045
# episode:   3 | score avg: 20.80 | loss: 0.043
# episode:   4 | score avg: 20.52 | loss: 0.046
# episode:   5 | score avg: 20.57 | loss: 0.044
# episode:   6 | score avg: 19.81 | loss: 0.060
# episode:   7 | score avg: 19.13 | loss: 0.038
# episode:   8 | score avg: 18.82 | loss: 0.052
# episode:   9 | score avg: 18.74 | loss: 0.051
# episode:  10 | score avg: 19.66 | loss: 0.037
# episode:  11 | score avg: 19.20 | loss: 0.059
# episode:  12 | score avg: 18.48 | loss: 0.060
# episode:  13 | score avg: 17.73 | loss: 0.071
# episode:  14 | score avg: 17.46 | loss: 0.054
# episode:  15 | score avg: 17.21 | loss: 0.052
# episode:  16 | score avg: 17.79 | loss: 0.041
# episode:  17 | score avg: 17.81 | loss: 0.047
# episode:  18 | score avg: 17.23 | loss: 0.060
# episode:  19 | score avg: 16.91 | loss: 0.052
# episode:  20 | score avg: 17.02 | loss: 0.041
# episode:  21 | score avg: 16.41 | loss: 0.057
# episode:  22 | score avg: 16.07 | loss: 0.058
# episode:  23 | score avg: 15.47 | loss: 0.055
# episode:  24 | score avg: 16.02 | loss: 0.042
# episode:  25 | score avg: 16.82 | loss: 0.041
# episode:  26 | score avg: 16.74 | loss: 0.055
# episode:  27 | score avg: 16.66 | loss: 0.053
# episode:  28 | score avg: 17.00 | loss: 0.045
# episode:  29 | score avg: 19.00 | loss: 0.033
# episode:  30 | score avg: 18.20 | loss: 0.065
# episode:  31 | score avg: 21.38 | loss: 0.032
# episode:  32 | score avg: 21.54 | loss: 0.047
# episode:  33 | score avg: 26.59 | loss: 0.044
# episode:  34 | score avg: 25.23 | loss: 0.106
# episode:  35 | score avg: 24.30 | loss: 0.070
# episode:  36 | score avg: 23.17 | loss: 0.122
# episode:  37 | score avg: 22.16 | loss: 0.123
# episode:  38 | score avg: 21.84 | loss: 0.064
# episode:  39 | score avg: 23.46 | loss: 0.039
# episode:  40 | score avg: 25.01 | loss: 0.038
# episode:  41 | score avg: 27.21 | loss: 0.032
# episode:  42 | score avg: 26.69 | loss: 0.065
# episode:  43 | score avg: 27.62 | loss: 0.027
# episode:  44 | score avg: 29.06 | loss: 0.064
# episode:  45 | score avg: 28.35 | loss: 0.168
# episode:  46 | score avg: 27.22 | loss: 0.211
# episode:  47 | score avg: 27.10 | loss: 0.123
# episode:  48 | score avg: 26.69 | loss: 0.082
# episode:  49 | score avg: 25.42 | loss: 0.192
# episode:  50 | score avg: 25.38 | loss: 0.096
# episode:  51 | score avg: 24.04 | loss: 0.173
# episode:  52 | score avg: 27.33 | loss: 0.050
# episode:  53 | score avg: 28.20 | loss: 0.074
# episode:  54 | score avg: 27.28 | loss: 0.121
# episode:  55 | score avg: 27.05 | loss: 0.084
# episode:  56 | score avg: 29.85 | loss: 0.055
# episode:  57 | score avg: 31.16 | loss: 0.083
# episode:  58 | score avg: 29.95 | loss: 0.163
# episode:  59 | score avg: 30.85 | loss: 0.096
# episode:  60 | score avg: 30.87 | loss: 0.083
# episode:  61 | score avg: 29.28 | loss: 0.166
# episode:  62 | score avg: 29.35 | loss: 0.119
# episode:  63 | score avg: 29.02 | loss: 0.065
# episode:  64 | score avg: 27.52 | loss: 0.125
# episode:  65 | score avg: 26.86 | loss: 0.094
# episode:  66 | score avg: 27.38 | loss: 0.079
# episode:  67 | score avg: 26.94 | loss: 0.146
# episode:  68 | score avg: 27.05 | loss: 0.119
# episode:  69 | score avg: 31.64 | loss: 0.052
# episode:  70 | score avg: 33.68 | loss: 0.068
# episode:  71 | score avg: 33.11 | loss: 0.117
# episode:  72 | score avg: 34.20 | loss: 0.107
# episode:  73 | score avg: 32.58 | loss: 0.149
# episode:  74 | score avg: 33.72 | loss: 0.076
# episode:  75 | score avg: 32.65 | loss: 0.114
# episode:  76 | score avg: 30.98 | loss: 0.116
# episode:  77 | score avg: 29.39 | loss: 0.084
# episode:  78 | score avg: 32.35 | loss: 0.053
# episode:  79 | score avg: 30.81 | loss: 0.121
# episode:  80 | score avg: 30.63 | loss: 0.063
# episode:  81 | score avg: 29.57 | loss: 0.093
# episode:  82 | score avg: 32.41 | loss: 0.038
# episode:  83 | score avg: 37.87 | loss: 0.073
# episode:  84 | score avg: 36.68 | loss: 0.158
# episode:  85 | score avg: 49.61 | loss: 0.052
# episode:  86 | score avg: 51.85 | loss: 0.068
# episode:  87 | score avg: 58.97 | loss: 0.044
# episode:  88 | score avg: 64.77 | loss: 0.110
# episode:  89 | score avg: 62.39 | loss: 0.278
# episode:  90 | score avg: 65.75 | loss: 0.124
# episode:  91 | score avg: 67.28 | loss: 0.148
# episode:  92 | score avg: 66.05 | loss: 0.151
# episode:  93 | score avg: 67.15 | loss: 0.150
# episode:  94 | score avg: 66.43 | loss: 0.159
# episode:  95 | score avg: 68.99 | loss: 0.125
# episode:  96 | score avg: 68.69 | loss: 0.175
# episode:  97 | score avg: 69.42 | loss: 0.151
# episode:  98 | score avg: 66.88 | loss: 0.133
# episode:  99 | score avg: 69.09 | loss: 0.058
# episode: 100 | score avg: 67.98 | loss: 0.198
# episode: 101 | score avg: 67.28 | loss: 0.172
# episode: 102 | score avg: 74.26 | loss: 0.019
# episode: 103 | score avg: 86.73 | loss: 0.080
# episode: 104 | score avg: 85.66 | loss: 0.057
# episode: 105 | score avg: 83.09 | loss: 0.244
# episode: 106 | score avg: 78.38 | loss: 0.305
# episode: 107 | score avg: 86.04 | loss: 0.097
# episode: 108 | score avg: 95.54 | loss: 0.010
# episode: 109 | score avg: 97.99 | loss: 0.142
# episode: 110 | score avg: 99.59 | loss: 0.148
# episode: 111 | score avg: 95.93 | loss: 0.238
# episode: 112 | score avg: 95.34 | loss: 0.007
# episode: 113 | score avg: 104.60 | loss: 0.102
# episode: 114 | score avg: 112.84 | loss: 0.118
# episode: 115 | score avg: 118.46 | loss: 0.011
# episode: 116 | score avg: 116.61 | loss: 0.002
# episode: 117 | score avg: 122.15 | loss: 0.005
# episode: 118 | score avg: 121.74 | loss: 0.004
# episode: 119 | score avg: 129.36 | loss: 0.004
# episode: 120 | score avg: 130.03 | loss: 0.155
# episode: 121 | score avg: 124.62 | loss: 0.246
# episode: 122 | score avg: 124.86 | loss: 0.019
# episode: 123 | score avg: 127.27 | loss: 0.152
# episode: 124 | score avg: 140.45 | loss: 0.093
# episode: 125 | score avg: 144.00 | loss: 0.119
# episode: 126 | score avg: 138.70 | loss: 0.248
# episode: 127 | score avg: 142.13 | loss: 0.139
# episode: 128 | score avg: 144.52 | loss: 0.145
# episode: 129 | score avg: 141.17 | loss: 0.207
# episode: 130 | score avg: 147.55 | loss: 0.110
# episode: 131 | score avg: 149.20 | loss: 0.140
# episode: 132 | score avg: 146.88 | loss: 0.160
# episode: 133 | score avg: 155.59 | loss: 0.104
# episode: 134 | score avg: 148.43 | loss: 0.248
# episode: 135 | score avg: 169.79 | loss: 0.076
# episode: 136 | score avg: 162.51 | loss: 0.220
# episode: 137 | score avg: 155.36 | loss: 0.176
# episode: 138 | score avg: 155.72 | loss: 0.153
# episode: 139 | score avg: 149.85 | loss: 0.136
# episode: 140 | score avg: 139.26 | loss: 0.429
# episode: 141 | score avg: 146.84 | loss: 0.032
# episode: 142 | score avg: 142.65 | loss: 0.089
# episode: 143 | score avg: 138.49 | loss: 0.041
# episode: 144 | score avg: 135.84 | loss: 0.049
# episode: 145 | score avg: 124.66 | loss: 0.774
# episode: 146 | score avg: 141.79 | loss: 0.066
# episode: 147 | score avg: 137.11 | loss: 0.114
# episode: 148 | score avg: 148.80 | loss: 0.035
# episode: 149 | score avg: 169.12 | loss: 0.023
# episode: 150 | score avg: 199.11 | loss: 0.037
# episode: 151 | score avg: 203.00 | loss: 0.073
# episode: 152 | score avg: 207.10 | loss: 0.017
# episode: 153 | score avg: 199.09 | loss: 0.017
# episode: 154 | score avg: 190.18 | loss: 0.019
# episode: 155 | score avg: 184.56 | loss: 0.012
# episode: 156 | score avg: 178.20 | loss: 0.015
# episode: 157 | score avg: 171.58 | loss: 0.009
# episode: 158 | score avg: 162.73 | loss: 0.015
# episode: 159 | score avg: 156.15 | loss: 0.005
# episode: 160 | score avg: 153.64 | loss: 0.009
# episode: 161 | score avg: 151.07 | loss: 0.023
# episode: 162 | score avg: 150.47 | loss: 0.022
# episode: 163 | score avg: 150.62 | loss: 0.018
# episode: 164 | score avg: 147.96 | loss: 0.020
# episode: 165 | score avg: 150.96 | loss: 0.017
# episode: 166 | score avg: 149.27 | loss: 0.014
# episode: 167 | score avg: 146.34 | loss: 0.019
# episode: 168 | score avg: 151.61 | loss: 0.008
# episode: 169 | score avg: 150.74 | loss: 0.010
# episode: 170 | score avg: 149.77 | loss: 0.254
# episode: 171 | score avg: 151.49 | loss: 0.008
# episode: 172 | score avg: 151.74 | loss: 0.190
# episode: 173 | score avg: 160.17 | loss: 0.006
# episode: 174 | score avg: 161.05 | loss: 0.005
# episode: 175 | score avg: 162.15 | loss: 0.001
# episode: 176 | score avg: 162.13 | loss: 0.118
# episode: 177 | score avg: 159.62 | loss: 0.003
# episode: 178 | score avg: 162.16 | loss: 0.064
# episode: 179 | score avg: 162.04 | loss: 0.013
# episode: 180 | score avg: 165.44 | loss: 0.012
# episode: 181 | score avg: 184.39 | loss: 0.015
# episode: 182 | score avg: 201.75 | loss: 0.053
# episode: 183 | score avg: 231.58 | loss: 0.075
# episode: 184 | score avg: 258.42 | loss: 0.058
# episode: 185 | score avg: 282.58 | loss: 0.075
# episode: 186 | score avg: 304.32 | loss: 0.063
# episode: 187 | score avg: 295.29 | loss: 0.074
# episode: 188 | score avg: 283.66 | loss: 0.050
# episode: 189 | score avg: 283.79 | loss: 0.042
# episode: 190 | score avg: 287.61 | loss: 0.036
# episode: 191 | score avg: 299.05 | loss: 0.061
# episode: 192 | score avg: 295.05 | loss: 0.040
# episode: 193 | score avg: 290.14 | loss: 0.055
# episode: 194 | score avg: 274.63 | loss: 0.046
# episode: 195 | score avg: 261.17 | loss: 0.040
# episode: 196 | score avg: 250.35 | loss: 0.033
# episode: 197 | score avg: 238.81 | loss: 0.035
# episode: 198 | score avg: 229.93 | loss: 0.030
# episode: 199 | score avg: 219.84 | loss: 0.035
# episode: 200 | score avg: 209.96 | loss: 0.038
# episode: 201 | score avg: 204.36 | loss: 0.029
# episode: 202 | score avg: 194.12 | loss: 0.044
# episode: 203 | score avg: 185.51 | loss: 0.040
# episode: 204 | score avg: 181.26 | loss: 0.032
# episode: 205 | score avg: 176.83 | loss: 0.036
# episode: 206 | score avg: 175.25 | loss: 0.036
# episode: 207 | score avg: 169.63 | loss: 0.042
# episode: 208 | score avg: 169.06 | loss: 0.046
# episode: 209 | score avg: 181.76 | loss: 0.064
# episode: 210 | score avg: 213.58 | loss: 0.025
# episode: 211 | score avg: 242.22 | loss: 0.077
# episode: 212 | score avg: 268.00 | loss: 0.061
# episode: 213 | score avg: 291.20 | loss: 0.081
# episode: 214 | score avg: 312.08 | loss: 0.082
# episode: 215 | score avg: 330.87 | loss: 0.063
# episode: 216 | score avg: 347.79 | loss: 0.076
# episode: 217 | score avg: 363.01 | loss: 0.077
# episode: 218 | score avg: 376.71 | loss: 0.075
# episode: 219 | score avg: 389.04 | loss: 0.073
# episode: 220 | score avg: 400.13 | loss: 0.074
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# c:\users\inpyo\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:3334: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# %load test.py
import sys
import gym
import pylab
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.initializers import RandomUniform


# 정책 신경망과 가치 신경망 생성
class A2C(tf.keras.Model):
    def __init__(self, action_size):
        super(A2C, self).__init__()
        self.actor_fc = Dense(24, activation='tanh')
        self.actor_out = Dense(action_size, activation='softmax',
                               kernel_initializer=RandomUniform(-1e-3, 1e-3))
        self.critic_fc1 = Dense(24, activation='tanh')
        self.critic_fc2 = Dense(24, activation='tanh')
        self.critic_out = Dense(1,
                                kernel_initializer=RandomUniform(-1e-3, 1e-3))

    def call(self, x):
        actor_x = self.actor_fc(x)
        policy = self.actor_out(actor_x)

        critic_x = self.critic_fc1(x)
        critic_x = self.critic_fc2(critic_x)
        value = self.critic_out(critic_x)
        return policy, value



# 카트폴 예제에서의 액터-크리틱(A2C) 에이전트
class A2CAgent:
    def __init__(self, action_size):
        # 행동의 크기 정의
        self.action_size = action_size

        # 정책신경망과 가치신경망 생성
        self.model = A2C(self.action_size)
        self.model.load_weights("./save_model/trained/model")

    # 정책신경망의 출력을 받아 확률적으로 행동을 선택
    def get_action(self, state):
        policy, _ = self.model(state)
        policy = np.array(policy[0])
        return np.random.choice(self.action_size, 1, p=policy)[0]


if __name__ == "__main__":
    # CartPole-v1 환경, 최대 타임스텝 수가 500
    env = gym.make('CartPole-v1')
    # 환경으로부터 상태와 행동의 크기를 받아옴
    state_size = env.observation_space.shape[0]
    action_size = env.action_space.n

    # 액터-크리틱(A2C) 에이전트 생성
    agent = A2CAgent(action_size)

    num_episode = 10
    for e in range(num_episode):
        done = False
        score = 0
        state = env.reset()
        state = np.reshape(state, [1, state_size])

        while not done:
            env.render()

            action = agent.get_action(state)
            next_state, reward, done, info = env.step(action)
            next_state = np.reshape(next_state, [1, state_size])

            score += reward
            state = next_state

            if done:
                print("episode: {:3d} | score: {:3d}".format(e, int(score)))
# Out:
# WARNING:tensorflow:Layer a2c_1 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# episode:   0 | score: 500
# episode:   1 | score: 500
# episode:   2 | score: 500
# episode:   3 | score: 500
# episode:   4 | score: 500
# episode:   5 | score: 500
# episode:   6 | score: 500
# episode:   7 | score: 500
# episode:   8 | score: 500
# episode:   9 | score: 500
